# %%
# take any dataset
#pruning -> used to reduce the overfitting for decission treee
# laso->complete
#ridge -> minimize the overall effect
"""apply the learnings
take the dataset do the preprocessing
1decision tree
2 logistic  regression
accuracy recall precisiion f1 score give the conclusion
"""

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, Lasso


data = fetch_california_housing()
x = data.data
y = data.target

# %%
X_train,Y_train , X_test,Y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
tree = DecisionTreeRegressor(random_state=42)
tree.fit(X_train, y_train)

print("Decision Tree")
print("Training:", tree.score(X_train, y_train))
print("Testing :", tree.score(X_test, y_test))


tree = DecisionTreeRegressor(
    max_depth = 5,
    random_state = 42
)
print("\n pruning Decision Tree")
print("Training:", pruned_tree.score(X_train, y_train))
print("Testing :", pruned_tree.score(X_test, y_test))
# Out:
# Decision Tree
# Training: 1.0
# Testing : 0.622075845135081
#
#  pruning Decision Tree
# Training: 0.6376786573648903
# Testing : 0.5997321244428706

# %%
ridge = Ridge(alpha=1.0)

ridge.fit(X_train, y_train)

print("\nRidge")
print("Training:", ridge.score(X_train, y_train))
print("Testing :", ridge.score(X_test, y_test))
# Out:
# Ridge
# Training: 0.6125511245209703
# Testing : 0.5758549611440138

# %%
lasso = Lasso(alpha=0.01)

lasso.fit(X_train, y_train)

print("\nLasso")
print("Training:", lasso.score(X_train, y_train))
print("Testing :", lasso.score(X_test, y_test))
# Out:
# Lasso
# Training: 0.6083136321985072
# Testing : 0.5845196673976367
